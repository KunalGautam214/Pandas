# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 114)
pd.set_option('display.max_rows', 114)

# %%
df.head()
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
#
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time     Remote  Apples
# 2           Employed, full-time     Remote  Apples
# 3           Employed, full-time     Remote  Apples
# 4            Student, full-time        NaN  Apples
# 5            Student, full-time        NaN  Apples
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 2           Hobby;Contribute to open-source projects;Other...
# 3           Hobby;Contribute to open-source projects;Other...
# 4                                                         NaN
# 5                                                         NaN
#
#                                                       EdLevel  \
# ResponseId
# 1                                   Primary/elementary school
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4           Some college/university study without earning ...
# 5           Secondary school (e.g. American high school, G...
#
#                                                     LearnCode  \
# ResponseId
# 1                                      Books / Physical media
# 2           Books / Physical media;Colleague;On the job tr...
# 3           Books / Physical media;Colleague;On the job tr...
# 4           Other online resources (e.g., videos, blogs, f...
# 5           Other online resources (e.g., videos, blogs, f...
#
#                                               LearnCodeOnline  \
# ResponseId
# 1                                                         NaN
# 2           Technical documentation;Blogs;Books;Written Tu...
# 3           Technical documentation;Blogs;Books;Written Tu...
# 4           Stack Overflow;How-to videos;Interactive tutorial
# 5           Technical documentation;Blogs;Written Tutorial...
#
#                                                       TechDoc YearsCode  \
# ResponseId
# 1                                                         NaN       NaN
# 2           API document(s) and/or SDK document(s);User gu...        20
# 3           API document(s) and/or SDK document(s);User gu...        37
# 4                                                         NaN         4
# 5           API document(s) and/or SDK document(s);User gu...         9
#
#            YearsCodePro                DevType OrgSize PurchaseInfluence  \
# ResponseId
# 1                   NaN                    NaN     NaN               NaN
# 2                    17  Developer, full-stack     NaN               NaN
# 3                    27   Developer Experience     NaN               NaN
# 4                   NaN  Developer, full-stack     NaN               NaN
# 5                   NaN  Developer, full-stack     NaN               NaN
#
#            BuyNewTool BuildvsBuy TechEndorse  \
# ResponseId
# 1                 NaN        NaN         NaN
# 2                 NaN        NaN         NaN
# 3                 NaN        NaN         NaN
# 4                 NaN        NaN         NaN
# 5                 NaN        NaN         NaN
#
#                                                       Country Currency  \
# ResponseId
# 1                                    United States of America      NaN
# 2           United Kingdom of Great Britain and Northern I...      NaN
# 3           United Kingdom of Great Britain and Northern I...      NaN
# 4                                                      Canada      NaN
# 5                                                      Norway      NaN
#
#             CompTotal                             LanguageHaveWorkedWith  \
# ResponseId
# 1                 NaN                                                NaN
# 2                 NaN  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 3                 NaN                                                 C#
# 4                 NaN  C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 5                 NaN            C++;HTML/CSS;JavaScript;Lua;Python;Rust
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2           Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 3                                                          C#
# 4           HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 5                          C++;HTML/CSS;JavaScript;Lua;Python
#
#                                               LanguageAdmired  \
# ResponseId
# 1                                                         NaN
# 2           Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 3                                                          C#
# 4           HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 5                          C++;HTML/CSS;JavaScript;Lua;Python
#
#                      DatabaseHaveWorkedWith      DatabaseWantToWorkWith  \
# ResponseId
# 1                                       NaN                         NaN
# 2               Dynamodb;MongoDB;PostgreSQL                  PostgreSQL
# 3                Firebase Realtime Database  Firebase Realtime Database
# 4           MongoDB;MySQL;PostgreSQL;SQLite    MongoDB;MySQL;PostgreSQL
# 5                         PostgreSQL;SQLite           PostgreSQL;SQLite
#
#                        DatabaseAdmired  \
# ResponseId
# 1                                  NaN
# 2                           PostgreSQL
# 3           Firebase Realtime Database
# 4             MongoDB;MySQL;PostgreSQL
# 5                    PostgreSQL;SQLite
#
#                               PlatformHaveWorkedWith  \
# ResponseId
# 1                                                NaN
# 2           Amazon Web Services (AWS);Heroku;Netlify
# 3                                       Google Cloud
# 4            Amazon Web Services (AWS);Fly.io;Heroku
# 5                                                NaN
#
#                               PlatformWantToWorkWith  \
# ResponseId
# 1                                                NaN
# 2           Amazon Web Services (AWS);Heroku;Netlify
# 3                                       Google Cloud
# 4                   Amazon Web Services (AWS);Vercel
# 5                                                NaN
#
#                                      PlatformAdmired  \
# ResponseId
# 1                                                NaN
# 2           Amazon Web Services (AWS);Heroku;Netlify
# 3                                       Google Cloud
# 4                          Amazon Web Services (AWS)
# 5                                                NaN
#
#                             WebframeHaveWorkedWith  \
# ResponseId
# 1                                              NaN
# 2                    Express;Next.js;Node.js;React
# 3                                     ASP.NET CORE
# 4           jQuery;Next.js;Node.js;React;WordPress
# 5                                              NaN
#
#                       WebframeWantToWorkWith               WebframeAdmired  \
# ResponseId
# 1                                        NaN                           NaN
# 2           Express;Htmx;Node.js;React;Remix         Express;Node.js;React
# 3                               ASP.NET CORE                  ASP.NET CORE
# 4               jQuery;Next.js;Node.js;React  jQuery;Next.js;Node.js;React
# 5                                        NaN                           NaN
#
#              EmbeddedHaveWorkedWith EmbeddedWantToWorkWith    EmbeddedAdmired  \
# ResponseId
# 1                               NaN                    NaN                NaN
# 2                               NaN                    NaN                NaN
# 3                       Rasberry Pi            Rasberry Pi        Rasberry Pi
# 4                       Rasberry Pi                    NaN                NaN
# 5           CMake;Cargo;Rasberry Pi      CMake;Rasberry Pi  CMake;Rasberry Pi
#
#                                      MiscTechHaveWorkedWith  \
# ResponseId
# 1                                                       NaN
# 2                                                       NaN
# 3           .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 4                              NumPy;Pandas;Ruff;TensorFlow
# 5                                                       NaN
#
#                                      MiscTechWantToWorkWith  \
# ResponseId
# 1                                                       NaN
# 2                                                       NaN
# 3           .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 4                                                       NaN
# 5                                                       NaN
#
#                                             MiscTechAdmired  \
# ResponseId
# 1                                                       NaN
# 2                                                       NaN
# 3           .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 4                                                       NaN
# 5                                                       NaN
#
#                                 ToolsTechHaveWorkedWith  \
# ResponseId
# 1                                                   NaN
# 2           Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 3                                               MSBuild
# 4                                        Docker;npm;Pip
# 5                                          APT;Make;npm
#
#                                 ToolsTechWantToWorkWith  \
# ResponseId
# 1                                                   NaN
# 2           Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 3                                               MSBuild
# 4                                 Docker;Kubernetes;npm
# 5                                              APT;Make
#
#                                        ToolsTechAdmired  \
# ResponseId
# 1                                                   NaN
# 2           Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 3                                               MSBuild
# 4                                            Docker;npm
# 5                                              APT;Make
#
#                    NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 1                                           NaN
# 2           PyCharm;Visual Studio Code;WebStorm
# 3                                 Visual Studio
# 4                                           NaN
# 5                                           Vim
#
#                    NEWCollabToolsWantToWorkWith  \
# ResponseId
# 1                                           NaN
# 2           PyCharm;Visual Studio Code;WebStorm
# 3                                 Visual Studio
# 4                                           NaN
# 5                                           Vim
#
#                           NEWCollabToolsAdmired        OpSysPersonal use  \
# ResponseId
# 1                                           NaN                      NaN
# 2           PyCharm;Visual Studio Code;WebStorm            MacOS;Windows
# 3                                 Visual Studio                  Windows
# 4                                           NaN                      NaN
# 5                                           Vim  Other (please specify):
#
#            OpSysProfessional use  \
# ResponseId
# 1                            NaN
# 2                          MacOS
# 3                        Windows
# 4                            NaN
# 5                            NaN
#
#                                OfficeStackAsyncHaveWorkedWith  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5           GitHub Discussions;Markdown File;Obsidian;Stac...
#
#                        OfficeStackAsyncWantToWorkWith  \
# ResponseId
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5           GitHub Discussions;Markdown File;Obsidian
#
#                               OfficeStackAsyncAdmired  \
# ResponseId
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5           GitHub Discussions;Markdown File;Obsidian
#
#                            OfficeStackSyncHaveWorkedWith  \
# ResponseId
# 1                                                    NaN
# 2                                  Microsoft Teams;Slack
# 3           Google Chat;Google Meet;Microsoft Teams;Zoom
# 4                                                    NaN
# 5                                       Discord;Whatsapp
#
#            OfficeStackSyncWantToWorkWith        OfficeStackSyncAdmired  \
# ResponseId
# 1                                    NaN                           NaN
# 2                                  Slack                         Slack
# 3           Google Chat;Google Meet;Zoom  Google Chat;Google Meet;Zoom
# 4                                    NaN                           NaN
# 5                       Discord;Whatsapp              Discord;Whatsapp
#
#            AISearchDevHaveWorkedWith AISearchDevWantToWorkWith  \
# ResponseId
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# 3                                NaN                       NaN
# 4                                NaN                       NaN
# 5                                NaN                       NaN
#
#            AISearchDevAdmired  \
# ResponseId
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
#
#                                                    NEWSOSites  \
# ResponseId
# 1           I have never visited Stack Overflow or the Sta...
# 2           Stack Overflow for Teams (private knowledge sh...
# 3           Stack Overflow;Stack Exchange;Stack Overflow B...
# 4                                              Stack Overflow
# 5           Stack Overflow for Teams (private knowledge sh...
#
#                        SOVisitFreq SOAccount              SOPartFreq  \
# ResponseId
# 1                              NaN       NaN                     NaN
# 2           Multiple times per day       Yes  Multiple times per day
# 3           Multiple times per day       Yes  Multiple times per day
# 4            Daily or almost daily        No                     NaN
# 5           Multiple times per day       Yes  Multiple times per day
#
#                                                         SOHow  \
# ResponseId
# 1                                                         NaN
# 2           Quickly finding code solutions;Finding reliabl...
# 3           Quickly finding code solutions;Finding reliabl...
# 4                              Quickly finding code solutions
# 5           Quickly finding code solutions;Engage with com...
#
#                      SOComm                 AISelect          AISent  \
# ResponseId
# 1                       NaN                      Yes  Very favorable
# 2           Yes, definitely  No, and I don't plan to             NaN
# 3           Yes, definitely  No, and I don't plan to             NaN
# 4            No, not really                      Yes  Very favorable
# 5           Yes, definitely  No, and I don't plan to             NaN
#
#                                                         AIBen           AIAcc  \
# ResponseId
# 1                                       Increase productivity             NaN
# 2                                                         NaN             NaN
# 3                                                         NaN             NaN
# 4           Increase productivity;Greater efficiency;Impro...  Somewhat trust
# 5                                                         NaN             NaN
#
#                                 AIComplex  \
# ResponseId
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4           Bad at handling complex tasks
# 5                                     NaN
#
#                                         AIToolCurrently Using  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Learning about a codebase;Project planning;Wri...
# 5                                                         NaN
#
#                                     AIToolInterested in Using  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Testing code;Committing and reviewing code;Pre...
# 5                                                         NaN
#
#            AIToolNot interested in Using  \
# ResponseId
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
#
#                                    AINextMuch more integrated AINextNo change  \
# ResponseId
# 1                                                         NaN             NaN
# 2                                                         NaN             NaN
# 3                                                         NaN             NaN
# 4           Learning about a codebase;Project planning;Wri...             NaN
# 5                                                         NaN             NaN
#
#            AINextMore integrated AINextLess integrated  \
# ResponseId
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN
# 5                            NaN                   NaN
#
#            AINextMuch less integrated AIThreat  \
# ResponseId
# 1                                 NaN      NaN
# 2                                 NaN      NaN
# 3                                 NaN      NaN
# 4                                 NaN       No
# 5                                 NaN      NaN
#
#                                                      AIEthics  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Circulating misinformation or disinformation;M...
# 5                                                         NaN
#
#                                  AIChallenges TBranch                  ICorPM  \
# ResponseId
# 1                                         NaN      No                     NaN
# 2                                         NaN     Yes  Individual contributor
# 3                                         NaN      No                     NaN
# 4           Don’t trust the output or answers     NaN                     NaN
# 5                                         NaN     NaN                     NaN
#
#             WorkExp Knowledge_1 Knowledge_2 Knowledge_3 Knowledge_4  \
# ResponseId
# 1               NaN         NaN         NaN         NaN         NaN
# 2              17.0       Agree    Disagree       Agree       Agree
# 3               NaN         NaN         NaN         NaN         NaN
# 4               NaN         NaN         NaN         NaN         NaN
# 5               NaN         NaN         NaN         NaN         NaN
#
#            Knowledge_5                 Knowledge_6 Knowledge_7 Knowledge_8  \
# ResponseId
# 1                  NaN                         NaN         NaN         NaN
# 2                Agree  Neither agree nor disagree    Disagree       Agree
# 3                  NaN                         NaN         NaN         NaN
# 4                  NaN                         NaN         NaN         NaN
# 5                  NaN                         NaN         NaN         NaN
#
#            Knowledge_9 Frequency_1 Frequency_2 Frequency_3 TimeSearching  \
# ResponseId
# 1                  NaN         NaN         NaN         NaN           NaN
# 2                Agree         NaN         NaN         NaN           NaN
# 3                  NaN         NaN         NaN         NaN           NaN
# 4                  NaN         NaN         NaN         NaN           NaN
# 5                  NaN         NaN         NaN         NaN           NaN
#
#            TimeAnswering Frustration ProfessionalTech ProfessionalCloud  \
# ResponseId
# 1                    NaN         NaN              NaN               NaN
# 2                    NaN         NaN              NaN               NaN
# 3                    NaN         NaN              NaN               NaN
# 4                    NaN         NaN              NaN               NaN
# 5                    NaN         NaN              NaN               NaN
#
#            ProfessionalQuestion Industry  JobSatPoints_1  JobSatPoints_4  \
# ResponseId
# 1                           NaN      NaN             NaN             NaN
# 2                           NaN      NaN             0.0             0.0
# 3                           NaN      NaN             NaN             NaN
# 4                           NaN      NaN             NaN             NaN
# 5                           NaN      NaN             NaN             NaN
#
#             JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  \
# ResponseId
# 1                      NaN             NaN             NaN             NaN
# 2                      0.0             0.0             0.0             0.0
# 3                      NaN             NaN             NaN             NaN
# 4                      NaN             NaN             NaN             NaN
# 5                      NaN             NaN             NaN             NaN
#
#             JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  \
# ResponseId
# 1                      NaN              NaN              NaN
# 2                      0.0              0.0              0.0
# 3                      NaN              NaN              NaN
# 4                      NaN              NaN              NaN
# 5                      NaN              NaN              NaN
#
#                      SurveyLength SurveyEase  ConvertedCompYearly  JobSat
# ResponseId
# 1                             NaN        NaN                  NaN     NaN
# 2                             NaN        NaN                  NaN     NaN
# 3           Appropriate in length       Easy                  NaN     NaN
# 4                        Too long       Easy                  NaN     NaN
# 5                       Too short       Easy                  NaN     NaN

# %%
schema_df.head()
# Out:
#                qid                                           question  \
# qname
# MainBranch    QID2  Which of the following options best describes ...
# Age         QID127                                 What is your age?*
# Employment  QID296  Which of the following best describes your cur...
# RemoteWork  QID308  Which best describes your current work situation?
# Check       QID341  Just checking to make sure you are paying atte...
#
#            force_resp type selector
# qname
# MainBranch       True   MC     SAVR
# Age              True   MC     SAVR
# Employment       True   MC     MAVR
# RemoteWork      False   MC     SAVR
# Check            True   MC     SAVR

# %%
schema_df.set_index('qname', inplace=True)

# %%
schema_df.loc['AIThreat', 'question']
# Out:
# 'Do you believe AI is a threat to your current job?'

# %%
schema_df.iloc[0]
# Out:
# type                                                       MC
# qid                                                      QID2
# question    Which of the following options best describes ...
# selector                                                 SAVR
# Name: MainBranch, dtype: object

# %%
schema_df.sort_index(ascending=False)
# Out:
#                         type     qid  \
# qname
# YearsCodePro              MC   QID34
# YearsCode                 MC   QID32
# WorkExp               Slider  QID288
# Webframe              Matrix  QID264
# ToolsTech             Matrix  QID275
# TimeSearching             MC  QID291
# TimeAnswering             MC  QID292
# TechEndorse               MC  QID335
# TechDoc                   MC  QID331
# TBranch                   MC  QID299
# SurveyLength              MC  QID132
# SurveyEase                MC  QID133
# SOVisitFreq               MC  QID100
# SOTeamsUsage              MC  QID286
# SOPartFreq                MC  QID102
# SOHow                     MC  QID334
# SOComm                    MC  QID106
# SOAccount                 MC  QID101
# RemoteWork                MC  QID308
# PurchaseInfluence         MC  QID278
# ProfessionalTech          MC  QID304
# ProfessionalQuestion      MC  QID333
# ProfessionalCloud         MC  QID332
# Platform              Matrix  QID263
# OrgSize                   MC   QID29
# OpSys                 Matrix   QID71
# OfficeStackSync       Matrix  QID307
# OfficeStackAsync      Matrix  QID282
# NEWSOSites                MC  QID266
# NEWCollabTools        Matrix  QID274
# MiscTech              Matrix  QID265
# MainBranch                MC    QID2
# LearnCodeOnline           MC  QID281
# LearnCode                 MC  QID276
# Language              Matrix  QID233
# Knowledge_9               MC  QID289
# Knowledge_8               MC  QID289
# Knowledge_7               MC  QID289
# Knowledge_6               MC  QID289
# Knowledge_5               MC  QID289
# Knowledge_4               MC  QID289
# Knowledge_3               MC  QID289
# Knowledge_2               MC  QID289
# Knowledge_1               MC  QID289
# Knowledge             Matrix  QID289
# JobSatPoints_9            MC  QID337
# JobSatPoints_8            MC  QID337
# JobSatPoints_7            MC  QID337
# JobSatPoints_6            MC  QID337
# JobSatPoints_5            MC  QID337
# JobSatPoints_4            MC  QID337
# JobSatPoints_11           MC  QID337
# JobSatPoints_10           MC  QID337
# JobSatPoints_1            MC  QID337
# JobSatPoints              CS  QID337
# JobSat                    MC  QID336
# Industry                  MC  QID326
# ICorPM                    MC  QID287
# Frustration               MC  QID342
# Frequency_3               MC  QID290
# Frequency_2               MC  QID290
# Frequency_1               MC  QID290
# Frequency             Matrix  QID290
# Employment                MC  QID296
# Embedded              Matrix  QID340
# EdLevel                   MC   QID25
# DevType                   MC   QID31
# Database              Matrix  QID262
# Currency                  MC   QID50
# Country                   MC    QID6
# CompTotal                 TE   QID51
# CodingActivities          MC  QID297
# Check                     MC  QID341
# BuyNewTool                MC  QID279
# BuildvsBuy                MC  QID330
# Age                       MC  QID127
# AITool                Matrix  QID319
# AIThreat                  MC  QID338
# AISent                    MC  QID315
# AISelect                  MC  QID314
# AISearchDev           Matrix  QID327
# AINext                Matrix  QID320
# AIEthics                  MC  QID339
# AIComplex                 MC  QID343
# AIChallenges              MC  QID346
# AIBen                     MC  QID324
# AIAcc                     MC  QID316
#
#                                                                question  \
# qname
# YearsCodePro          NOT including education, how many years have y...
# YearsCode             Including any education, how many years have y...
# WorkExp               How many years of working experience do you have?
# Webframe              Which <b>web frameworks and web technologies</...
# ToolsTech             Which <b>developer </b><strong>tools for compi...
# TimeSearching         On an average day, how much time do you typica...
# TimeAnswering         On an average day, how much time do you typica...
# TechEndorse           What product feature do you care about most wh...
# TechDoc               What is the source of the technical documentat...
# TBranch               <span style="font-size:16px;">Would you like t...
# SurveyLength          How do you feel about the length of the survey...
# SurveyEase            How easy or difficult was this survey to compl...
# SOVisitFreq           How frequently would you say you visit Stack O...
# SOTeamsUsage               Does your team use Stack Overflow for Teams?
# SOPartFreq            How frequently would you say you participate i...
# SOHow                 How do you use Stack Overflow?  Select all tha...
# SOComm                Do you consider yourself a member of the Stack...
# SOAccount                         Do you have a Stack Overflow account?
# RemoteWork            Which best describes your current work situation?
# PurchaseInfluence     What level of influence do you, personally, ha...
# ProfessionalTech                                        My company has:
# ProfessionalQuestion  When you have a technical question at work, wh...
# ProfessionalCloud     At my company, our applications, databases and...
# Platform              Which <b>cloud platforms</b> have you done ext...
# OrgSize               Approximately how many people are employed by ...
# OpSys                 What is the primary <b>operating system</b> in...
# OfficeStackSync       Which <b>communication tools</b> did you use r...
# OfficeStackAsync      Which <b>collaborative work management and/or ...
# NEWSOSites            Which of the following Stack Overflow sites ha...
# NEWCollabTools        Which <strong>development environments</strong...
# MiscTech              Which <b>other frameworks and libraries</b> ha...
# MainBranch            Which of the following options best describes ...
# LearnCodeOnline       What online resources do you use to learn to c...
# LearnCode              How do you learn to code? Select all that apply.
# Language              Which <b>programming, scripting, and markup la...
# Knowledge_9           I have asked my employer to reimburse me for t...
# Knowledge_8           I feel like I have the tools and/or resources ...
# Knowledge_7           Waiting on answers to questions often causes i...
# Knowledge_6           I often find myself answering questions that I...
# Knowledge_5           I know which system or resource to use to find...
# Knowledge_4           I am able to quickly find answers to my questi...
# Knowledge_3           I can find up-to-date information within my or...
# Knowledge_2           Knowledge silos prevent me from getting ideas ...
# Knowledge_1           I have interactions with people outside of my ...
# Knowledge             Please rate your level of agreement with the f...
# JobSatPoints_9        Being a power user of a tool, developer langua...
# JobSatPoints_8        Designing and building environments, databases...
# JobSatPoints_7        Learning and using new technology, including p...
# JobSatPoints_6        Improving quality of code and developer enviro...
# JobSatPoints_5                           Securing data and environments
# JobSatPoints_4                              Contributing to open source
# JobSatPoints_11       A well-staffed/sourced internal network that m...
# JobSatPoints_10            Working with new and/or top-quality hardware
# JobSatPoints_1                             Driving strategy for my team
# JobSatPoints          Assign points to the following attributes of y...
# JobSat                How satisfied are you in your current professi...
# Industry                  What industry is the company you work for in?
# ICorPM                Are you an individual contributor or people ma...
# Frustration           Which of these company challenges causes you t...
# Frequency_3           Encountering knowledge silos (where one indivi...
# Frequency_2           Interacting with people outside of your immedi...
# Frequency_1           Needing help from people outside of your immed...
# Frequency             How frequently do you experience each of the f...
# Employment            Which of the following best describes your cur...
# Embedded              Which <b>embedded systems and technologies</b>...
# EdLevel               Which of the following best describes the high...
# DevType               Which of the following describes your current ...
# Database              Which <b>database environments </b>have you do...
# Currency              Which currency do you use day-to-day? If your ...
# Country               Where do you live? <span style="font-weight: b...
# CompTotal             What is your current total <b>annual</b> compe...
# CodingActivities      Which of the following best describes the code...
# Check                 Just checking to make sure you are paying atte...
# BuyNewTool            When buying a new tool or software, how do you...
# BuildvsBuy            When asked to provide a recommendation for sol...
# Age                                                  What is your age?*
# AITool                Which parts of your development workflow are y...
# AIThreat              Do you believe AI is a threat to your current ...
# AISent                How favorable is your stance on using AI tools...
# AISelect              Do you currently use AI tools in your developm...
# AISearchDev           Which <b>AI-powered search and developer tools...
# AINext                Thinking about how your job and process change...
# AIEthics              Which AI ethical responsibilities are most imp...
# AIComplex             How well do the AI tools you use in your devel...
# AIChallenges          What are the challenges to your company/whole ...
# AIBen                 For the AI tools you use as part of your devel...
# AIAcc                 How much do you trust the accuracy of the outp...
#
#                      selector
# qname
# YearsCodePro               DL
# YearsCode                  DL
# WorkExp               HSLIDER
# Webframe               Likert
# ToolsTech              Likert
# TimeSearching            SAVR
# TimeAnswering            SAVR
# TechEndorse              MAVR
# TechDoc                  MAVR
# TBranch                  SAVR
# SurveyLength             MAVR
# SurveyEase               MAVR
# SOVisitFreq              SAVR
# SOTeamsUsage             SAVR
# SOPartFreq               SAVR
# SOHow                    MAVR
# SOComm                   SAVR
# SOAccount                SAVR
# RemoteWork               SAVR
# PurchaseInfluence        SAVR
# ProfessionalTech         MAVR
# ProfessionalQuestion     SAVR
# ProfessionalCloud        SAVR
# Platform               Likert
# OrgSize                  SAVR
# OpSys                  Likert
# OfficeStackSync        Likert
# OfficeStackAsync       Likert
# NEWSOSites               MAVR
# NEWCollabTools         Likert
# MiscTech               Likert
# MainBranch               SAVR
# LearnCodeOnline          MAVR
# LearnCode                MAVR
# Language               Likert
# Knowledge_9              MAVR
# Knowledge_8              MAVR
# Knowledge_7              MAVR
# Knowledge_6              MAVR
# Knowledge_5              MAVR
# Knowledge_4              MAVR
# Knowledge_3              MAVR
# Knowledge_2              MAVR
# Knowledge_1              MAVR
# Knowledge              Likert
# JobSatPoints_9           MAVR
# JobSatPoints_8           MAVR
# JobSatPoints_7           MAVR
# JobSatPoints_6           MAVR
# JobSatPoints_5           MAVR
# JobSatPoints_4           MAVR
# JobSatPoints_11          MAVR
# JobSatPoints_10          MAVR
# JobSatPoints_1           MAVR
# JobSatPoints             VRTL
# JobSat                    NPS
# Industry                 SAVR
# ICorPM                   SAVR
# Frustration              MAVR
# Frequency_3              MAVR
# Frequency_2              MAVR
# Frequency_1              MAVR
# Frequency              Likert
# Employment               MAVR
# Embedded               Likert
# EdLevel                  SAVR
# DevType                  SAVR
# Database               Likert
# Currency                   DL
# Country                    DL
# CompTotal                  SL
# CodingActivities         MAVR
# Check                    SAVR
# BuyNewTool               MAVR
# BuildvsBuy               SAVR
# Age                      SAVR
# AITool                 Likert
# AIThreat                 SAVR
# AISent                   SAVR
# AISelect                 SAVR
# AISearchDev            Likert
# AINext                 Likert
# AIEthics                 MAVR
# AIComplex                SAVR
# AIChallenges             MAVR
# AIBen                    MAVR
# AIAcc                    SAVR

# %%
schema_df.reset_index(inplace=True)

# %%
schema_df
# Out:
#                    qname    type     qid  \
# 0                  AIAcc      MC  QID316
# 1                  AIBen      MC  QID324
# 2           AIChallenges      MC  QID346
# 3              AIComplex      MC  QID343
# 4               AIEthics      MC  QID339
# 5                 AINext  Matrix  QID320
# 6            AISearchDev  Matrix  QID327
# 7               AISelect      MC  QID314
# 8                 AISent      MC  QID315
# 9               AIThreat      MC  QID338
# 10                AITool  Matrix  QID319
# 11                   Age      MC  QID127
# 12            BuildvsBuy      MC  QID330
# 13            BuyNewTool      MC  QID279
# 14                 Check      MC  QID341
# 15      CodingActivities      MC  QID297
# 16             CompTotal      TE   QID51
# 17               Country      MC    QID6
# 18              Currency      MC   QID50
# 19              Database  Matrix  QID262
# 20               DevType      MC   QID31
# 21               EdLevel      MC   QID25
# 22              Embedded  Matrix  QID340
# 23            Employment      MC  QID296
# 24             Frequency  Matrix  QID290
# 25           Frequency_1      MC  QID290
# 26           Frequency_2      MC  QID290
# 27           Frequency_3      MC  QID290
# 28           Frustration      MC  QID342
# 29                ICorPM      MC  QID287
# 30              Industry      MC  QID326
# 31                JobSat      MC  QID336
# 32          JobSatPoints      CS  QID337
# 33        JobSatPoints_1      MC  QID337
# 34       JobSatPoints_10      MC  QID337
# 35       JobSatPoints_11      MC  QID337
# 36        JobSatPoints_4      MC  QID337
# 37        JobSatPoints_5      MC  QID337
# 38        JobSatPoints_6      MC  QID337
# 39        JobSatPoints_7      MC  QID337
# 40        JobSatPoints_8      MC  QID337
# 41        JobSatPoints_9      MC  QID337
# 42             Knowledge  Matrix  QID289
# 43           Knowledge_1      MC  QID289
# 44           Knowledge_2      MC  QID289
# 45           Knowledge_3      MC  QID289
# 46           Knowledge_4      MC  QID289
# 47           Knowledge_5      MC  QID289
# 48           Knowledge_6      MC  QID289
# 49           Knowledge_7      MC  QID289
# 50           Knowledge_8      MC  QID289
# 51           Knowledge_9      MC  QID289
# 52              Language  Matrix  QID233
# 53             LearnCode      MC  QID276
# 54       LearnCodeOnline      MC  QID281
# 55            MainBranch      MC    QID2
# 56              MiscTech  Matrix  QID265
# 57        NEWCollabTools  Matrix  QID274
# 58            NEWSOSites      MC  QID266
# 59      OfficeStackAsync  Matrix  QID282
# 60       OfficeStackSync  Matrix  QID307
# 61                 OpSys  Matrix   QID71
# 62               OrgSize      MC   QID29
# 63              Platform  Matrix  QID263
# 64     ProfessionalCloud      MC  QID332
# 65  ProfessionalQuestion      MC  QID333
# 66      ProfessionalTech      MC  QID304
# 67     PurchaseInfluence      MC  QID278
# 68            RemoteWork      MC  QID308
# 69             SOAccount      MC  QID101
# 70                SOComm      MC  QID106
# 71                 SOHow      MC  QID334
# 72            SOPartFreq      MC  QID102
# 73          SOTeamsUsage      MC  QID286
# 74           SOVisitFreq      MC  QID100
# 75            SurveyEase      MC  QID133
# 76          SurveyLength      MC  QID132
# 77               TBranch      MC  QID299
# 78               TechDoc      MC  QID331
# 79           TechEndorse      MC  QID335
# 80         TimeAnswering      MC  QID292
# 81         TimeSearching      MC  QID291
# 82             ToolsTech  Matrix  QID275
# 83              Webframe  Matrix  QID264
# 84               WorkExp  Slider  QID288
# 85             YearsCode      MC   QID32
# 86          YearsCodePro      MC   QID34
#
#                                              question selector
# 0   How much do you trust the accuracy of the outp...     SAVR
# 1   For the AI tools you use as part of your devel...     MAVR
# 2   What are the challenges to your company/whole ...     MAVR
# 3   How well do the AI tools you use in your devel...     SAVR
# 4   Which AI ethical responsibilities are most imp...     MAVR
# 5   Thinking about how your job and process change...   Likert
# 6   Which <b>AI-powered search and developer tools...   Likert
# 7   Do you currently use AI tools in your developm...     SAVR
# 8   How favorable is your stance on using AI tools...     SAVR
# 9   Do you believe AI is a threat to your current ...     SAVR
# 10  Which parts of your development workflow are y...   Likert
# 11                                 What is your age?*     SAVR
# 12  When asked to provide a recommendation for sol...     SAVR
# 13  When buying a new tool or software, how do you...     MAVR
# 14  Just checking to make sure you are paying atte...     SAVR
# 15  Which of the following best describes the code...     MAVR
# 16  What is your current total <b>annual</b> compe...       SL
# 17  Where do you live? <span style="font-weight: b...       DL
# 18  Which currency do you use day-to-day? If your ...       DL
# 19  Which <b>database environments </b>have you do...   Likert
# 20  Which of the following describes your current ...     SAVR
# 21  Which of the following best describes the high...     SAVR
# 22  Which <b>embedded systems and technologies</b>...   Likert
# 23  Which of the following best describes your cur...     MAVR
# 24  How frequently do you experience each of the f...   Likert
# 25  Needing help from people outside of your immed...     MAVR
# 26  Interacting with people outside of your immedi...     MAVR
# 27  Encountering knowledge silos (where one indivi...     MAVR
# 28  Which of these company challenges causes you t...     MAVR
# 29  Are you an individual contributor or people ma...     SAVR
# 30      What industry is the company you work for in?     SAVR
# 31  How satisfied are you in your current professi...      NPS
# 32  Assign points to the following attributes of y...     VRTL
# 33                       Driving strategy for my team     MAVR
# 34       Working with new and/or top-quality hardware     MAVR
# 35  A well-staffed/sourced internal network that m...     MAVR
# 36                        Contributing to open source     MAVR
# 37                     Securing data and environments     MAVR
# 38  Improving quality of code and developer enviro...     MAVR
# 39  Learning and using new technology, including p...     MAVR
# 40  Designing and building environments, databases...     MAVR
# 41  Being a power user of a tool, developer langua...     MAVR
# 42  Please rate your level of agreement with the f...   Likert
# 43  I have interactions with people outside of my ...     MAVR
# 44  Knowledge silos prevent me from getting ideas ...     MAVR
# 45  I can find up-to-date information within my or...     MAVR
# 46  I am able to quickly find answers to my questi...     MAVR
# 47  I know which system or resource to use to find...     MAVR
# 48  I often find myself answering questions that I...     MAVR
# 49  Waiting on answers to questions often causes i...     MAVR
# 50  I feel like I have the tools and/or resources ...     MAVR
# 51  I have asked my employer to reimburse me for t...     MAVR
# 52  Which <b>programming, scripting, and markup la...   Likert
# 53   How do you learn to code? Select all that apply.     MAVR
# 54  What online resources do you use to learn to c...     MAVR
# 55  Which of the following options best describes ...     SAVR
# 56  Which <b>other frameworks and libraries</b> ha...   Likert
# 57  Which <strong>development environments</strong...   Likert
# 58  Which of the following Stack Overflow sites ha...     MAVR
# 59  Which <b>collaborative work management and/or ...   Likert
# 60  Which <b>communication tools</b> did you use r...   Likert
# 61  What is the primary <b>operating system</b> in...   Likert
# 62  Approximately how many people are employed by ...     SAVR
# 63  Which <b>cloud platforms</b> have you done ext...   Likert
# 64  At my company, our applications, databases and...     SAVR
# 65  When you have a technical question at work, wh...     SAVR
# 66                                    My company has:     MAVR
# 67  What level of influence do you, personally, ha...     SAVR
# 68  Which best describes your current work situation?     SAVR
# 69              Do you have a Stack Overflow account?     SAVR
# 70  Do you consider yourself a member of the Stack...     SAVR
# 71  How do you use Stack Overflow?  Select all tha...     MAVR
# 72  How frequently would you say you participate i...     SAVR
# 73       Does your team use Stack Overflow for Teams?     SAVR
# 74  How frequently would you say you visit Stack O...     SAVR
# 75  How easy or difficult was this survey to compl...     MAVR
# 76  How do you feel about the length of the survey...     MAVR
# 77  <span style="font-size:16px;">Would you like t...     SAVR
# 78  What is the source of the technical documentat...     MAVR
# 79  What product feature do you care about most wh...     MAVR
# 80  On an average day, how much time do you typica...     SAVR
# 81  On an average day, how much time do you typica...     SAVR
# 82  Which <b>developer </b><strong>tools for compi...   Likert
# 83  Which <b>web frameworks and web technologies</...   Likert
# 84  How many years of working experience do you have?  HSLIDER
# 85  Including any education, how many years have y...       DL
# 86  NOT including education, how many years have y...       DL
