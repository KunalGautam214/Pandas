# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 114)
pd.set_option('display.max_rows', 114)

# %%
df.head()
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
#
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time     Remote  Apples
# 2           Employed, full-time     Remote  Apples
# 3           Employed, full-time     Remote  Apples
# 4            Student, full-time        NaN  Apples
# 5            Student, full-time        NaN  Apples
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 2           Hobby;Contribute to open-source projects;Other...
# ...

# %%
countries = ['India', 'Canada', 'Norway', 'United States of America', 'Germany']
filt = df['Country'].isin(countries)

# %%
df.loc[filt]
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 4                                       I am learning to code
# 5                              I am a developer by profession
# 6                                 I code primarily as a hobby
# 7           I am not primarily a developer, but I write co...
# ...                                                       ...
# 65384                                   I am learning to code
# 65414                                   I am learning to code
# 65416                             I code primarily as a hobby
# 65429                          I am a developer by profession
# 65436                          I am a developer by profession
#
#                            Age                          Employment  \
# ResponseId
# 1           Under 18 years old                 Employed, full-time
# ...

# %%
filt = (df['Country'] == 'India') & (df['CompTotal'] > 80000)

# %%
df.loc[~filt, ['Country', 'CompTotal']]
# Out:
#                                                       Country  CompTotal
# ResponseId
# 1                                    United States of America        NaN
# 2           United Kingdom of Great Britain and Northern I...        NaN
# 3           United Kingdom of Great Britain and Northern I...        NaN
# 4                                                      Canada        NaN
# 5                                                      Norway        NaN
# ...                                                       ...        ...
# 65433                                                     NaN        NaN
# 65434                                                     NaN        NaN
# 65435                                                     NaN        NaN
# 65436                                                 Germany        NaN
# 65437                                                     NaN        NaN
#
# [55269 rows x 2 columns]

# %%
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na=False) & (df['CompTotal'] > 80000)

# %%
df.loc[filt, ['Country', 'LanguageHaveWorkedWith', 'CompTotal']]
# Out:
#                                                       Country  \
# ResponseId
# 73                                                   Pakistan
# 380                                                    Turkey
# 390                                  United States of America
# 393         United Kingdom of Great Britain and Northern I...
# 396         United Kingdom of Great Britain and Northern I...
# ...                                                       ...
# 65253                                United States of America
# 65283                                                  Canada
# 65307                                               Singapore
# 65334                                                  Sweden
# 65354       United Kingdom of Great Britain and Northern I...
#
#                                        LanguageHaveWorkedWith  CompTotal
# ResponseId
# 73          Assembly;Bash/Shell (all shells);C;C++;HTML/CS...  2040000.0
# ...
