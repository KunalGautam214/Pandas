# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 114)
pd.set_option('display.max_rows', 114)

# %%
df.head(10)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                                       I am learning to code
# 5                              I am a developer by profession
# 6                                 I code primarily as a hobby
# 7           I am not primarily a developer, but I write co...
# 8                                       I am learning to code
# 9                                 I code primarily as a hobby
# 10                             I am a developer by profession
#
#                            Age  \
# ResponseId
# 1           Under 18 years old
# 2              35-44 years old
# 3              45-54 years old
# 4              18-24 years old
# 5              18-24 years old
# 6           Under 18 years old
# ...

# %%
df.apply(len, axis='columns')
# Out:
# ResponseId
# 1        113
# 2        113
# 3        113
# 4        113
# 5        113
#         ...
# 65433    113
# 65434    113
# 65435    113
# 65436    113
# 65437    113
# Length: 65437, dtype: int64

# %%
data = {
    'first': ['Python', 'Java', 'C', 'HTML'],
    'last': ['Programming', 'Core', 'Language', 'Web'],
    'email': ['PythonProgramming@email.com', 'JavaCore@email.com', 'CLanguage@email.com', 'HtmlWeb@email.com']
}

# %%
df_data = pd.DataFrame(data)

# %%
df_data
# Out:
#     first         last                        email
# 0  Python  Programming  PythonProgramming@email.com
# 1    Java         Core           JavaCore@email.com
# 2       C     Language          CLanguage@email.com
# 3    HTML          Web            HtmlWeb@email.com

# %%
df_data.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# dtype: int64

# %%
df_data['email'].apply(len)
# Out:
# 0    27
# 1    18
# 2    19
# 3    17
# Name: email, dtype: int64

# %%
df_data['email'] = df_data['email'].apply(lambda x: x.lower())

# %%
df_data
# Out:
#     first         last                        email
# 0  Python  Programming  pythonprogramming@email.com
# 1    Java         Core           javacore@email.com
# 2       C     Language          clanguage@email.com
# 3    HTML          Web            htmlweb@email.com

# %%
df_data.map(len)
# Out:
#    first  last  email
# 0      6    11     27
# 1      4     4     18
# 2      1     8     19
# 3      4     3     17

# %%
df_data = df_data.map(str.lower)

# %%
df_data
# Out:
#     first         last                        email
# 0  python  programming  pythonprogramming@email.com
# 1    java         core           javacore@email.com
# 2       c     language          clanguage@email.com
# 3    html          web            htmlweb@email.com

# %%
df_data['last'] = df_data['last'].map(str.upper)

# %%
df_data
# Out:
#     first         last                        email
# 0  python  PROGRAMMING  pythonprogramming@email.com
# 1    java         CORE           javacore@email.com
# 2       c     LANGUAGE          clanguage@email.com
# 3    html          WEB            htmlweb@email.com

# %%
df_data['last'].map({'WEB': 'web', 'CORE': 'core'})
# Out:
# 0     NaN
# 1    core
# 2     NaN
# 3     web
# Name: last, dtype: object

# %%
df_data['last'] = df_data['last'].replace({'WEB': 'web', 'CORE': 'core'})

# %%
df_data
# Out:
#     first         last                        email
# 0  python  PROGRAMMING  pythonprogramming@email.com
# 1    java         core           javacore@email.com
# 2       c     LANGUAGE          clanguage@email.com
# 3    html          web            htmlweb@email.com
