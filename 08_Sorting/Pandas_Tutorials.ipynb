# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 114)
pd.set_option('display.max_rows', 114)

# %%
df.head(10)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                                       I am learning to code
# 5                              I am a developer by profession
# 6                                 I code primarily as a hobby
# 7           I am not primarily a developer, but I write co...
# 8                                       I am learning to code
# 9                                 I code primarily as a hobby
# 10                             I am a developer by profession
#
#                            Age  \
# ResponseId
# 1           Under 18 years old
# 2              35-44 years old
# 3              45-54 years old
# 4              18-24 years old
# 5              18-24 years old
# 6           Under 18 years old
# ...

# %%
df.sort_values(by='Country', inplace=True)

# %%
df['Country'].head(50)
# Out:
# ResponseId
# 14673    Afghanistan
# 1378     Afghanistan
# 33453    Afghanistan
# 55671    Afghanistan
# 6942     Afghanistan
# 1328     Afghanistan
# 8815     Afghanistan
# 31476    Afghanistan
# 49949    Afghanistan
# 25201    Afghanistan
# 41147    Afghanistan
# 37549    Afghanistan
# 64494    Afghanistan
# 64869    Afghanistan
# 39346    Afghanistan
# 46020    Afghanistan
# 17375    Afghanistan
# 50987    Afghanistan
# 14613    Afghanistan
# 61493    Afghanistan
# 48576    Afghanistan
# 59308    Afghanistan
# 29914    Afghanistan
# 32421    Afghanistan
# 22246    Afghanistan
# 59278    Afghanistan
# 38003    Afghanistan
# 1566     Afghanistan
# 17567    Afghanistan
# 60268    Afghanistan
# 37968    Afghanistan
# 60332    Afghanistan
# 25712    Afghanistan
# 31269    Afghanistan
# 18321    Afghanistan
# 44402    Afghanistan
# 33102    Afghanistan
# 18723    Afghanistan
# 15329    Afghanistan
# 51544    Afghanistan
# 55953    Afghanistan
# 36195    Afghanistan
# ...

# %%
df.sort_values(by='Country', ascending=False, inplace=True)

# %%
df['Country'].head(50)
# Out:
# ResponseId
# 1224     Zimbabwe
# 38839    Zimbabwe
# 24506    Zimbabwe
# 57112    Zimbabwe
# 1160     Zimbabwe
# 13601    Zimbabwe
# 15651    Zimbabwe
# 24335    Zimbabwe
# 23007    Zimbabwe
# 42240    Zimbabwe
# 38823    Zimbabwe
# 53303    Zimbabwe
# 27737    Zimbabwe
# 14474    Zimbabwe
# 58145    Zimbabwe
# 63996    Zimbabwe
# 31485    Zimbabwe
# 2701     Zimbabwe
# 23742    Zimbabwe
# 20050    Zimbabwe
# 12040    Zimbabwe
# 23673    Zimbabwe
# 31445    Zimbabwe
# 26497    Zimbabwe
# 56035    Zimbabwe
# 14423    Zimbabwe
# 41324      Zambia
# 5984       Zambia
# 12245      Zambia
# 34768      Zambia
# 51499      Zambia
# 26078      Zambia
# 4216       Zambia
# 55481      Zambia
# 27694      Zambia
# 35287      Zambia
# 47666      Zambia
# 11540      Zambia
# 29623      Zambia
# 43222      Zambia
# 39192      Zambia
# 53683       Yemen
# 53620       Yemen
# 58856       Yemen
# 11834       Yemen
# 10601       Yemen
# 39821       Yemen
# 64307       Yemen
# 14833       Yemen
# ...

# %%
df.sort_values(by=['Country', 'CompTotal'], ascending=[True, False], inplace=True)

# %%
df.head(50)
# Out:
#                                                    MainBranch  \
# ResponseId
# 17375                          I am a developer by profession
# 8815                           I am a developer by profession
# 60332       I am not primarily a developer, but I write co...
# 1566                           I am a developer by profession
# 37549                          I am a developer by profession
# 61493       I am not primarily a developer, but I write co...
# 49949                          I am a developer by profession
# 14673                          I am a developer by profession
# 6942                           I am a developer by profession
# 14613                          I am a developer by profession
# 9825                           I am a developer by profession
# 55237       I am not primarily a developer, but I write co...
# 39346                          I am a developer by profession
# 48576                          I am a developer by profession
# ...

# %%
df[['Country', 'CompTotal']].nlargest(10, columns='CompTotal')
# Out:
#                                           Country      CompTotal
# ResponseId
# 14355       Democratic People's Republic of Korea  1.000000e+150
# 34279                                     Nomadic   1.000000e+65
# 17375                                 Afghanistan   1.000000e+53
# 8815                                  Afghanistan   1.000000e+44
# 20038                                       Niger   8.000000e+27
# 24678                                    Slovakia   1.000000e+20
# 27269                    United States of America   1.111111e+15
# 52486                                     Germany   3.040302e+14
# 46993                                       India   7.587459e+13
# 59888                    United States of America   7.777778e+12

# %%
df[['Country', 'CompTotal']].nsmallest(10, columns='CompTotal')
# Out:
#                 Country  CompTotal
# ResponseId
# 41147       Afghanistan        0.0
# 15329       Afghanistan        0.0
# 9948          Australia        0.0
# 15163         Australia        0.0
# 40089         Australia        0.0
# 50594         Australia        0.0
# 51644        Azerbaijan        0.0
# 24879        Bangladesh        0.0
# 57792            Brazil        0.0
# 6747             Brazil        0.0
