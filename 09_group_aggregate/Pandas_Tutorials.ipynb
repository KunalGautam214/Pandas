# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 114)
pd.set_option('display.max_rows', 114)

# %%
df.head()
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
#
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time     Remote  Apples
# 2           Employed, full-time     Remote  Apples
# 3           Employed, full-time     Remote  Apples
# 4            Student, full-time        NaN  Apples
# 5            Student, full-time        NaN  Apples
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 2           Hobby;Contribute to open-source projects;Other...
# ...

# %%
df['CompTotal'].median()
# Out:
# np.float64(110000.0)

# %%
df['Country'].mode()
# Out:
# 0    United States of America
# Name: Country, dtype: object

# %%
filt = df['Country'] == 'Germany'
df.loc[filt].shape
# Out:
# (4947, 113)

# %%
df['CompTotal'].mean()
# Out:
# np.float64(2.9638411381149976e+145)

# %%
df.describe()
# Out:
#            CompTotal       WorkExp  JobSatPoints_1  JobSatPoints_4  \
# count   3.374000e+04  29658.000000    29324.000000    29393.000000
# mean   2.963841e+145     11.466957       18.581094        7.522140
# std    5.444117e+147      9.168709       25.966221       18.422661
# min     0.000000e+00      0.000000        0.000000        0.000000
# 25%     6.000000e+04      4.000000        0.000000        0.000000
# 50%     1.100000e+05      9.000000       10.000000        0.000000
# 75%     2.500000e+05     16.000000       22.000000        5.000000
# max    1.000000e+150     50.000000      100.000000      100.000000
#
#        JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  \
# count    29411.000000    29450.000000     29448.00000    29456.000000
# mean        10.060857       24.343232        22.96522       20.278165
# std         21.833836       27.089360        27.01774       26.108110
# min          0.000000        0.000000         0.00000        0.000000
# ...

# %%
df['CompTotal'].describe()
# Out:
# count     3.374000e+04
# mean     2.963841e+145
# std      5.444117e+147
# min       0.000000e+00
# 25%       6.000000e+04
# 50%       1.100000e+05
# 75%       2.500000e+05
# max      1.000000e+150
# Name: CompTotal, dtype: float64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group(('India',))
# Out:
#                                                    MainBranch  \
# ResponseId
# 18                             I am a developer by profession
# 59          I am not primarily a developer, but I write co...
# 76                                      I am learning to code
# 90                                      I am learning to code
# 97                             I am a developer by profession
# ...                                                       ...
# 65340       I am not primarily a developer, but I write co...
# 65384                                   I am learning to code
# 65414                                   I am learning to code
# 65416                             I code primarily as a hobby
# 65429                          I am a developer by profession
#
#                         Age  \
# ResponseId
# 18          18-24 years old
# 59          18-24 years old
# 76          25-34 years old
# 90          25-34 years old
# 97          25-34 years old
# ...

# %%
country_grp.get_group(('Germany',))['CompTotal'].median()
# Out:
# np.float64(69000.0)

# %%
country_grp['CompTotal'].median().loc['Germany']
# Out:
# np.float64(69000.0)

# %%
country_grp['CompTotal'].value_counts()
# Out:
# Country      CompTotal
# Afghanistan  0.0          2
#              700000.0     2
#              1.0          1
#              2.0          1
#              9.0          1
#                          ..
# Zimbabwe     30000.0      1
#              36000.0      1
#              80000.0      1
#              82000.0      1
#              100000.0     1
# Name: count, Length: 10331, dtype: int64

# %%
country_grp['CompTotal'].value_counts().loc['India']
# Out:
# CompTotal
# 1.000000e+06    51
# 2.500000e+06    50
# 1.200000e+06    49
# 2.000000e+06    44
# 3.000000e+06    44
#                 ..
# 2.000000e+07     1
# 3.000000e+07     1
# 3.600000e+07     1
# 2.815000e+08     1
# 7.587459e+13     1
# Name: count, Length: 332, dtype: int64

# %%
country_grp['CompTotal'].agg(['median', 'mean'])
# Out:
#                                            median          mean
# Country
# Afghanistan                               26000.0  4.166667e+51
# Albania                                   90000.0  1.493638e+06
# Algeria                                  600000.0  7.415032e+05
# Andorra                                   40000.0  9.400000e+04
# Angola                                  1350000.0  3.412757e+07
# ...                                           ...           ...
# Venezuela, Bolivarian Republic of...      12600.0  2.091343e+04
# Viet Nam                              202000000.0  2.942487e+08
# Yemen                                     50000.0  1.295200e+06
# Zambia                                    49200.0  3.097925e+05
# Zimbabwe                                  18000.0  3.046000e+04
#
# [185 rows x 2 columns]

# %%
country_grp['CompTotal'].agg(['median', 'mean']).loc['India']
# Out:
# median    1.300000e+06
# mean      4.892193e+10
# Name: India, dtype: float64

# %%
filt = df['Country'] == 'India'

# %%
df.loc[filt]
# Out:
#                                                    MainBranch  \
# ResponseId
# 18                             I am a developer by profession
# 59          I am not primarily a developer, but I write co...
# 76                                      I am learning to code
# 90                                      I am learning to code
# 97                             I am a developer by profession
# ...                                                       ...
# 65340       I am not primarily a developer, but I write co...
# 65384                                   I am learning to code
# 65414                                   I am learning to code
# 65416                             I code primarily as a hobby
# 65429                          I am a developer by profession
#
#                         Age  \
# ResponseId
# 18          18-24 years old
# 59          18-24 years old
# 76          25-34 years old
# 90          25-34 years old
# 97          25-34 years old
# ...

# %%
df.loc[filt]['CompTotal'].value_counts(normalize=True)
# Out:
# CompTotal
# 1000000.0    0.032882
# 2500000.0    0.032237
# 1200000.0    0.031593
# 2000000.0    0.028369
# 3000000.0    0.028369
#                ...
# 7000.0       0.000645
# 1060000.0    0.000645
# 80000.0      0.000645
# 1352000.0    0.000645
# 264000.0     0.000645
# Name: proportion, Length: 332, dtype: float64

# %%
df.loc[filt, 'LanguageHaveWorkedWith'].str.contains('Python').value_counts()
# Out:
# LanguageHaveWorkedWith
# True     2128
# False    1930
# Name: count, dtype: int64

# %%
country_grp['LanguageHaveWorkedWith'].str.contains('Python').value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 country_grp['LanguageHaveWorkedWith'].str.contains('Python').value_counts()
#
# File ~\Desktop\CodewithKG\Lib\site-packages\pandas\core\groupby\groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x[filt]).str.contains('Python').value_counts()
# Out:
# LanguageHaveWorkedWith
# True     2128
# False    1930
# Name: count, dtype: int64

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').value_counts()).loc['India']
# Out:
# True     2128
# False    1930
# Name: LanguageHaveWorkedWith, dtype: int64

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum()).loc['United States of America']
# Out:
# np.int64(6251)
