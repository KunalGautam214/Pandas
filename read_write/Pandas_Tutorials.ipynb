# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 114)
pd.set_option('display.max_rows', 114)

# %%
df.head()
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
#
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time     Remote  Apples
# 2           Employed, full-time     Remote  Apples
# 3           Employed, full-time     Remote  Apples
# 4            Student, full-time        NaN  Apples
# 5            Student, full-time        NaN  Apples
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 2           Hobby;Contribute to open-source projects;Other...
# ...

# %%
filt = df['Country'] == 'India'

# %%
india_df = df.loc[filt]

# %%
india_df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 18                             I am a developer by profession
# 59          I am not primarily a developer, but I write co...
# 76                                      I am learning to code
# 90                                      I am learning to code
# 97                             I am a developer by profession
#
#                         Age  \
# ResponseId
# 18          18-24 years old
# 59          18-24 years old
# 76          25-34 years old
# 90          25-34 years old
# 97          25-34 years old
#
#                                                    Employment RemoteWork  \
# ResponseId
# 18          Independent contractor, freelancer, or self-em...     Remote
# 59                                         Student, full-time        NaN
# 76                         Not employed, but looking for work        NaN
# 90                                        Employed, full-time  In-person
# ...

# %%
india_df.to_csv('modified.csv')

# %%
india_df.to_excel('modified.xlsx')

# %%
india_df.to_csv('modified.tsv', sep='\t')

# %%
india_df.to_json('modified.json')

# %%
india_df.to_json('modified_records.json', orient='records')

# %%
excel_df = pd.read_excel('modified.xlsx', index_col='ResponseId')

# %%
excel_df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 18                             I am a developer by profession
# 59          I am not primarily a developer, but I write co...
# 76                                      I am learning to code
# 90                                      I am learning to code
# 97                             I am a developer by profession
#
#                         Age  \
# ResponseId
# 18          18-24 years old
# 59          18-24 years old
# 76          25-34 years old
# 90          25-34 years old
# 97          25-34 years old
#
#                                                    Employment RemoteWork  \
# ResponseId
# 18          Independent contractor, freelancer, or self-em...     Remote
# 59                                         Student, full-time        NaN
# 76                         Not employed, but looking for work        NaN
# 90                                        Employed, full-time  In-person
# ...

# %%
t_df = pd.read_csv('modified.tsv', sep='\t')

# %%
t_df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0          18                     I am a developer by profession
# 1          59  I am not primarily a developer, but I write co...
# 2          76                              I am learning to code
# 3          90                              I am learning to code
# 4          97                     I am a developer by profession
#
#                Age                                         Employment  \
# 0  18-24 years old  Independent contractor, freelancer, or self-em...
# 1  18-24 years old                                 Student, full-time
# 2  25-34 years old                 Not employed, but looking for work
# 3  25-34 years old                                Employed, full-time
# 4  25-34 years old                                Employed, full-time
#
#   RemoteWork   Check                                   CodingActivities  \
# 0     Remote  Apples  Hobby;Professional development or self-paced l...
# ...

# %%
j_df = pd.read_json('modified.json')

# %%
j_df.head()
# Out:
#                                            MainBranch              Age  \
# 18                     I am a developer by profession  18-24 years old
# 59  I am not primarily a developer, but I write co...  18-24 years old
# 76                              I am learning to code  25-34 years old
# 90                              I am learning to code  25-34 years old
# 97                     I am a developer by profession  25-34 years old
#
#                                            Employment RemoteWork   Check  \
# 18  Independent contractor, freelancer, or self-em...     Remote  Apples
# 59                                 Student, full-time       None  Apples
# 76                 Not employed, but looking for work       None  Apples
# 90                                Employed, full-time  In-person  Apples
# 97                                Employed, full-time     Remote  Apples
#
#                                      CodingActivities  \
# ...

# %%
sbi_df = pd.read_csv('https://raw.githubusercontent.com/KunalGautam214/Pandas/refs/heads/main/data/sbi.csv')

# %%
sbi_df.head()
# Out:
#          Date  series    OPEN    HIGH     LOW   PREV. CLOSE     ltp   close   \
# 0  20-Sep-2024      EQ  794.85  794.85  779.50        789.95  784.50  781.70
# 1  19-Sep-2024      EQ  795.05  801.35  784.05        792.75  791.50  789.95
# 2  18-Sep-2024      EQ  783.80  794.75  782.00        782.90  790.75  792.75
# 3  17-Sep-2024      EQ  785.60  787.50  780.55        785.55  782.75  782.90
# 4  16-Sep-2024      EQ  790.85  795.00  784.40        790.85  786.55  785.55
#
#     vwap   52W H   52W L       VOLUME               VALUE  No of trades
# 0  785.43   912.0   543.2  2,13,72,244  16,78,63,88,691.70      2,65,805
# 1  791.39   912.0   543.2  1,06,45,478   8,42,47,36,778.30      2,18,449
# 2  791.27   912.0   543.2  1,83,24,412  14,49,95,92,000.20      2,55,355
# 3  784.12   912.0   543.2  1,06,65,630   8,36,31,82,377.75      2,23,966
# 4  788.19   912.0   543.2    95,53,736   7,53,01,68,486.30      2,35,580
